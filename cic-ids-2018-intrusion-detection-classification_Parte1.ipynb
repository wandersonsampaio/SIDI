# %% [markdown]
# # CIC IDS 2018

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings
warnings.filterwarnings('ignore')

# %%
# %%time
dia1 = pd.read_csv('02-14-2018.csv', low_memory=False)
dia2 = pd.read_csv('02-15-2018.csv', low_memory=False)
dia3 = pd.read_csv('02-16-2018.csv', low_memory=False)
#dia4 = pd.read_csv('02-20-2018.csv', low_memory=False)
dia5 = pd.read_csv('02-21-2018.csv', low_memory=False)
dia6 = pd.read_csv('02-22-2018.csv', low_memory=False)
dia7 = pd.read_csv('02-23-2018.csv', low_memory=False)
dia8 = pd.read_csv('02-28-2018.csv', low_memory=False)
dia9 = pd.read_csv('03-01-2018.csv', low_memory=False)
dia10 = pd.read_csv('03-02-2018.csv', low_memory=False)
# Out:
# CPU times: total: 49.5 s
# Wall time: 54.7 s

# %%
#Somando 
dia1['Label'].value_counts()
# Out:
# Benign            667626
# FTP-BruteForce    193360
# SSH-Bruteforce    187589
# Name: Label, dtype: int64

# %%
#Somando 
dia2['Label'].value_counts()
# Out:
# Benign                   996077
# DoS attacks-GoldenEye     41508
# DoS attacks-Slowloris     10990
# Name: Label, dtype: int64

# %%
#Somando 
dia3['Label'].value_counts()
# Out:
# DoS attacks-Hulk            461912
# Benign                      446772
# DoS attacks-SlowHTTPTest    139890
# Name: Label, dtype: int64

# %%
#Somando 
dia5['Label'].value_counts()
# Out:
# DDOS attack-HOIC        686012
# Benign                  360833
# DDOS attack-LOIC-UDP      1730
# Name: Label, dtype: int64

# %%
#Somando 
dia6['Label'].value_counts()
# Out:
# Benign              1048213
# Brute Force -Web        249
# Brute Force -XSS         79
# SQL Injection            34
# Name: Label, dtype: int64

# %%
dia7['Label'].value_counts()
# Out:
# Benign              1048009
# Brute Force -Web        362
# Brute Force -XSS        151
# SQL Injection            53
# Name: Label, dtype: int64

# %%
#Somando 
dia8['Label'].value_counts()
# Out:
# Benign           544200
# Infilteration     68871
# Name: Label, dtype: int64

# %%
#Somando 
dia9['Label'].value_counts()
# Out:
# Benign           238037
# Infilteration     93063
# Name: Label, dtype: int64

# %%
#Somando 
dia10['Label'].value_counts()
# Out:
# Benign    762384
# Bot       286191
# Name: Label, dtype: int64

# %%
instancia_total = dia1.shape[0]
instancia_b = dia1[dia1['Label'] == 'Benign'].shape[0]
instancia_f = dia1[dia1['Label'] == 'FTP-BruteForce'].shape[0]
instancia_s = dia1[dia1['Label'] == 'SSH-Bruteforce'].shape[0]


instancia_total_2 = dia2.shape[0]
instancia_b_2 = dia2[dia2['Label'] == 'Benign'].shape[0]
instancia_dos_g = dia2[dia2['Label'] == 'DoS attacks-GoldenEye'].shape[0]
instancia_dos_s = dia2[dia2['Label'] == 'DoS attacks-Slowloris'].shape[0]


instancia_total_3 = dia3.shape[0]
instancia_b_3 = dia3[dia3['Label'] == 'Benign'].shape[0]
instancia_dos_h = dia3[dia3['Label'] == 'DoS attacks-Hulk'].shape[0]
instancia_dos_s3 = dia3[dia3['Label'] == 'DoS attacks-SlowHTTPTest'].shape[0]

instancia_total_5 = dia5.shape[0]
instancia_b_5 = dia5[dia5['Label'] == 'Benign'].shape[0]
instancia_dos_hoic = dia5[dia5['Label'] == 'DDOS attack-HOIC'].shape[0]
instancia_dos_loic = dia5[dia5['Label'] == 'DDOS attack-LOIC-UDP'].shape[0]


instancia_total_6 = dia6.shape[0]
instancia_b_6 = dia6[dia6['Label'] == 'Benign'].shape[0]
instancia_bruteforce_web = dia6[dia6['Label'] == 'Brute Force -Web'].shape[0]
instancia_bruteforce_xss = dia6[dia6['Label'] == 'Brute Force -XSS'].shape[0]
instancia_sql_inject = dia6[dia6['Label'] == 'SQL Injection'].shape[0]

instancia_total_7 = dia7.shape[0]
instancia_b_7 = dia7[dia7['Label'] == 'Benign'].shape[0]
instancia_bruteforce_web_7 = dia7[dia7['Label'] == 'Brute Force -Web'].shape[0]
instancia_bruteforce_xss_7 = dia7[dia7['Label'] == 'Brute Force -XSS'].shape[0]
instancia_sql_inject_7 = dia7[dia7['Label'] == 'SQL Injection'].shape[0]


instancia_total_8 = dia8.shape[0]
instancia_b_8 = dia8[dia8['Label'] == 'Benign'].shape[0]
instancia_Infilteration_8 = dia8[dia8['Label'] == 'Infilteration'].shape[0]

instancia_total_9 = dia9.shape[0]
instancia_b_9 = dia9[dia9['Label'] == 'Benign'].shape[0]
instancia_Infilteration_9 = dia9[dia9['Label'] == 'Infilteration'].shape[0]

instancia_total_10 = dia10.shape[0]
instancia_b_10 = dia10[dia10['Label'] == 'Benign'].shape[0]
instancia_bot_10 = dia10[dia10['Label'] == 'Bot'].shape[0]

# %%
print ("Dia 02-14-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-14-2018 ".format(instancia_b, (instancia_b*100/instancia_total)))

print("{} linhas consideradas FTP-BruteForce, o que é equivalente a {}% do dataset 02-14-2018".format(instancia_f, (instancia_f*100/instancia_total)))

print("{} linhas consideradas SSH-Bruteforce, o que é equivalente a {}% do dataset 02-14-2018".format(instancia_s, (instancia_s*100/instancia_total)))
################################################################################################
print ("\n")
print ("Dia 02-15-2018 \n")
print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-15-2018 ".format(instancia_b_2, (instancia_b_2*100/instancia_total_2)))

print("{} linhas consideradas DoS attacks-GoldenEye, o que é equivalente a {}% do dataset 02-15-2018".format(instancia_dos_g, (instancia_dos_g*100/instancia_total_2)))

print("{} linhas consideradas DoS attacks-Slowloris, o que é equivalente a {}% do dataset 02-15-2018".format(instancia_dos_s, (instancia_dos_s*100/instancia_total_2)))
###################################################################################
print ("\n")
print ("Dia 02-16-2018 \n")
print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-16-2018 ".format(instancia_b_3, (instancia_b_3*100/instancia_total_3)))

print("{} linhas consideradas DoS attacks-Hulk, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_h, (instancia_dos_h*100/instancia_total_3)))

print("{} linhas consideradas DoS attacks-SlowHTTPTest, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_s3, (instancia_dos_s3*100/instancia_total_3)))


print ("\n")
print ("Dia 02-21-2018 \n")
print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-16-2018 ".format(instancia_b_5, (instancia_b_5*100/instancia_total_5)))

print("{} linhas consideradas DoS attacks-Hulk, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_hoic, (instancia_dos_hoic*100/instancia_total_5)))

print("{} linhas consideradas DoS attacks-SlowHTTPTest, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_loic, (instancia_dos_loic*100/instancia_total_5)))


print ("\n")
print ("Dia 02-22-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-22-2018 ".format(instancia_b_6, (instancia_b_6*100/instancia_total_6)))
print("{} linhas consideradas Brute Force -Web, o que é equivalente a {}% do dataset 02-22-2018".format(instancia_bruteforce_web, (instancia_bruteforce_web*100/instancia_total_6)))
print("{} linhas consideradas Brute Force -XSS, o que é equivalente a {}% do dataset 02-22-2018".format(instancia_bruteforce_xss, (instancia_bruteforce_xss*100/instancia_total_6)))
print("{} linhas consideradas SQL Injection, o que é equivalente a {}% do dataset 02-22-2018".format(instancia_sql_inject, (instancia_sql_inject*100/instancia_total_6)))

print ("\n")
print ("Dia 02-23-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-23-2018 ".format(instancia_b_7, (instancia_b_7*100/instancia_total_7)))
print("{} linhas consideradas Brute Force -Web, o que é equivalente a {}% do dataset 02-23-2018".format(instancia_bruteforce_web_7, (instancia_bruteforce_web_7*100/instancia_total_7)))
print("{} linhas consideradas Brute Force -XSS, o que é equivalente a {}% do dataset 02-23-2018".format(instancia_bruteforce_xss_7, (instancia_bruteforce_xss_7*100/instancia_total_7)))
print ("Dia 02-14-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-14-2018 ".format(instancia_b, (instancia_b*100/instancia_total)))

print("{} linhas consideradas FTP-BruteForce, o que é equivalente a {}% do dataset 02-14-2018".format(instancia_f, (instancia_f*100/instancia_total)))

print("{} linhas consideradas SSH-Bruteforce, o que é equivalente a {}% do dataset 02-14-2018".format(instancia_s, (instancia_s*100/instancia_total)))
################################################################################################
print ("\n")
print ("Dia 02-15-2018 \n")
print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-15-2018 ".format(instancia_b_2, (instancia_b_2*100/instancia_total_2)))

print("{} linhas consideradas DoS attacks-GoldenEye, o que é equivalente a {}% do dataset 02-15-2018".format(instancia_dos_g, (instancia_dos_g*100/instancia_total_2)))

print("{} linhas consideradas DoS attacks-Slowloris, o que é equivalente a {}% do dataset 02-15-2018".format(instancia_dos_s, (instancia_dos_s*100/instancia_total_2)))
###################################################################################
print ("\n")
print ("Dia 02-16-2018 \n")
print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-16-2018 ".format(instancia_b_3, (instancia_b_3*100/instancia_total_3)))

print("{} linhas consideradas DoS attacks-Hulk, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_h, (instancia_dos_h*100/instancia_total_3)))

print("{} linhas consideradas DoS attacks-SlowHTTPTest, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_s3, (instancia_dos_s3*100/instancia_total_3)))


print ("\n")
print ("Dia 02-21-2018 \n")
print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-16-2018 ".format(instancia_b_5, (instancia_b_5*100/instancia_total_5)))

print("{} linhas consideradas DoS attacks-Hulk, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_hoic, (instancia_dos_hoic*100/instancia_total_5)))

print("{} linhas consideradas DoS attacks-SlowHTTPTest, o que é equivalente a {}% do dataset 02-16-2018".format(instancia_dos_loic, (instancia_dos_loic*100/instancia_total_5)))


print ("\n")
print ("Dia 02-22-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-22-2018 ".format(instancia_b_6, (instancia_b_6*100/instancia_total_6)))
print("{} linhas consideradas Brute Force -Web, o que é equivalente a {}% do dataset 02-22-2018".format(instancia_bruteforce_web, (instancia_bruteforce_web*100/instancia_total_6)))
print("{} linhas consideradas Brute Force -XSS, o que é equivalente a {}% do dataset 02-22-2018".format(instancia_bruteforce_xss, (instancia_bruteforce_xss*100/instancia_total_6)))
print("{} linhas consideradas SQL Injection, o que é equivalente a {}% do dataset 02-22-2018".format(instancia_sql_inject, (instancia_sql_inject*100/instancia_total_6)))

print ("\n")
print ("Dia 02-23-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-23-2018 ".format(instancia_b_7, (instancia_b_7*100/instancia_total_7)))
print("{} linhas consideradas Brute Force -Web, o que é equivalente a {}% do dataset 02-23-2018".format(instancia_bruteforce_web_7, (instancia_bruteforce_web_7*100/instancia_total_7)))
print("{} linhas consideradas Brute Force -XSS, o que é equivalente a {}% do dataset 02-23-2018".format(instancia_bruteforce_xss_7, (instancia_bruteforce_xss_7*100/instancia_total_7)))
print("{} linhas consideradas SQL Injection, o que é equivalente a {}% do dataset 02-23-2018".format(instancia_sql_inject_7, (instancia_sql_inject_7*100/instancia_total_7)))

print ("\n")
print ("Dia 02-28-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 02-28-2018 ".format(instancia_b_8, (instancia_b_8*100/instancia_total_8)))
print("{} linhas consideradas Infilteration, o que é equivalente a {}% do dataset 02-28-2018".format(instancia_Infilteration_8, (instancia_Infilteration_8*100/instancia_total_8)))

print ("\n")
print ("Dia 03-01-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 03-01-2018 ".format(instancia_b_9, (instancia_b_9*100/instancia_total_9)))
print("{} linhas consideradas Infilteration, o que é equivalente a {}% do dataset 03-01-2018".format(instancia_Infilteration_9, (instancia_Infilteration_9*100/instancia_total_9)))

print ("\n")
print ("Dia 03-02-2018 \n")

print("{} linhas consideradas Benign, o que é equivalente a {}% do dataset 03-01-2018 ".format(instancia_b_10, (instancia_b_10*100/instancia_total_10)))
print("{} linhas consideradas Infilteration, o que é equivalente a {}% do dataset 03-01-2018".format(instancia_bot_10, (instancia_bot_10*100/instancia_total_10)))
# Out:
# Dia 02-14-2018
#
# 667626 linhas consideradas Benign, o que é equivalente a 63.66983763679279% do dataset 02-14-2018
# 193360 linhas consideradas FTP-BruteForce, o que é equivalente a 18.440264168037576% do dataset 02-14-2018
# 187589 linhas consideradas SSH-Bruteforce, o que é equivalente a 17.889898195169636% do dataset 02-14-2018
#
#
# Dia 02-15-2018
#
# 996077 linhas consideradas Benign, o que é equivalente a 94.99339579906064% do dataset 02-15-2018
# 41508 linhas consideradas DoS attacks-GoldenEye, o que é equivalente a 3.958515127673271% do dataset 02-15-2018
# 10990 linhas consideradas DoS attacks-Slowloris, o que é equivalente a 1.0480890732660992% do dataset 02-15-2018
#
#
# Dia 02-16-2018
#
# 446772 linhas consideradas Benign, o que é equivalente a 42.6075794364537% do dataset 02-16-2018
# 461912 linhas consideradas DoS attacks-Hulk, o que é equivalente a 44.05144510544797% do dataset 02-16-2018
# ...

# %%
#Criando um novo dataset apenas com o Label Benign
dia1_benign = dia1[dia1['Label'] == 'Benign']
regulador = instancia_f +instancia_s
dia1_benign = dia1_benign.sample(n = regulador)

#Criando um novo dataset apenas com o Label Benign
dia2_benign = dia2[dia2['Label'] == 'Benign']
regulador2 = instancia_dos_g + instancia_dos_s
dia2_benign = dia2_benign.sample(n = regulador2)

#Criando um novo dataset apenas com o Label Benign
dia6_benign = dia6[dia6['Label'] == 'Benign']
regulador6 = instancia_bruteforce_web + instancia_bruteforce_xss + instancia_sql_inject
dia6_benign = dia6_benign.sample(n = regulador6)

#Criando um novo dataset apenas com o Label Benign
dia7_benign = dia7[dia7['Label'] == 'Benign']
regulador7 = instancia_bruteforce_web_7 + instancia_bruteforce_xss_7 + instancia_sql_inject_7
dia7_benign = dia7_benign.sample(n = regulador7)

#Criando um novo dataset apenas com o Label Benign
dia8_benign = dia8[dia8['Label'] == 'Benign']
regulador8 = instancia_Infilteration_8
dia8_benign = dia8_benign.sample(n = regulador8)

#Criando um novo dataset apenas com o Label Benign
dia9_benign = dia9[dia9['Label'] == 'Benign']
regulador9 = instancia_Infilteration_9
dia9_benign = dia9_benign.sample(n = regulador9)

#Criando um novo dataset apenas com o Label Benign
dia10_benign = dia10[dia10['Label'] == 'Benign']
regulador10 = instancia_bot_10
dia10_benign = dia10_benign.sample(n = regulador10)

# %%
dia1_no_benign = dia1
dia1_no_benign.drop(dia1_no_benign.loc[dia1_no_benign['Label']=='Benign'].index, inplace=True)

dia2_no_benign = dia2
dia2_no_benign.drop(dia2_no_benign.loc[dia2_no_benign['Label']=='Benign'].index, inplace=True)

dia6_no_benign = dia6
dia6_no_benign.drop(dia6_no_benign.loc[dia6_no_benign['Label']=='Benign'].index, inplace=True)

dia7_no_benign = dia7
dia7_no_benign.drop(dia7_no_benign.loc[dia7_no_benign['Label']=='Benign'].index, inplace=True)

dia8_no_benign = dia8
dia8_no_benign.drop(dia8_no_benign.loc[dia8_no_benign['Label']=='Benign'].index, inplace=True)

dia9_no_benign = dia9
dia9_no_benign.drop(dia9_no_benign.loc[dia9_no_benign['Label']=='Benign'].index, inplace=True)

dia10_no_benign = dia10
dia10_no_benign.drop(dia10_no_benign.loc[dia10_no_benign['Label']=='Benign'].index, inplace=True)

# %%
novo_dia1 = pd.concat([dia1_benign, dia1_no_benign], axis=0)
novo_dia2 = pd.concat([dia2_benign, dia2_no_benign], axis=0)
novo_dia6 = pd.concat([dia6_benign, dia6_no_benign], axis=0)
novo_dia7 = pd.concat([dia7_benign, dia7_no_benign], axis=0)
novo_dia8 = pd.concat([dia8_benign, dia8_no_benign], axis=0)
novo_dia9 = pd.concat([dia9_benign, dia9_no_benign], axis=0)
novo_dia10 = pd.concat([dia10_benign, dia10_no_benign], axis=0)

# %%
instancia_novo_dia1 = novo_dia1.shape[0]
instancia_novo_dia2 = novo_dia2.shape[0]
instancia_novo_dia6 = novo_dia6.shape[0]
instancia_novo_dia7 = novo_dia7.shape[0]
instancia_novo_dia8 = novo_dia8.shape[0]
instancia_novo_dia9 = novo_dia9.shape[0]
instancia_novo_dia10 = novo_dia10.shape[0]


instancia_novo_b = novo_dia1[novo_dia1['Label'] == 'Benign'].shape[0]
instancia_novo_b_2 = novo_dia2[novo_dia2['Label'] == 'Benign'].shape[0]
instancia_novo_b_6 = novo_dia6[novo_dia6['Label'] == 'Benign'].shape[0]
instancia_novo_b_7 = novo_dia7[novo_dia7['Label'] == 'Benign'].shape[0]
instancia_novo_b_8 = novo_dia8[novo_dia8['Label'] == 'Benign'].shape[0]
instancia_novo_b_9 = novo_dia9[novo_dia9['Label'] == 'Benign'].shape[0]
instancia_novo_b_10 = novo_dia10[novo_dia10['Label'] == 'Benign'].shape[0]

# %%
novo_dia10.shape
# Out:
# (572382, 80)

# %%
print("{} linhas consideradas Benign no dataset original, o que é equivalente a {}% do dataset".format(instancia_b, (instancia_b*100/instancia_total)))
print("{} linhas consideradas Benign no novo dataset original, o que é equivalente a {}% do dataset".format(instancia_novo_b, (instancia_novo_b*100/instancia_novo_dia1)))
print("Foram removidas {} linhas consideradas Benign do antigo dataset, o que é equivalente a {}% do dataset".format((instancia_b-regulador),((instancia_b-regulador)*100/instancia_total)))
print ("\n")
print("{} linhas consideradas Benign no dataset original, o que é equivalente a {}% do dataset".format(instancia_b_2, (instancia_b_2*100/instancia_total_2)))
print("{} linhas consideradas Benign no novo dataset original, o que é equivalente a {}% do dataset".format(instancia_novo_b_2, (instancia_novo_b_2*100/instancia_novo_dia2)))
print("Foram removidas {} linhas consideradas Benign do antigo dataset, o que é equivalente a {}% do dataset".format((instancia_b_2-regulador2),((instancia_b_2-regulador2)*100/instancia_total_2)))

print ("\n")

print("{} linhas consideradas Benign no dataset original, o que é equivalente a {}% do dataset".format(instancia_b_6, (instancia_b_6*100/instancia_total_6)))
print("{} linhas consideradas Benign no novo dataset original, o que é equivalente a {}% do dataset".format(instancia_novo_b_6, (instancia_novo_b_6*100/instancia_novo_dia6)))
print("Foram removidas {} linhas consideradas Benign do antigo dataset, o que é equivalente a {}% do dataset".format((instancia_b_6-regulador6),((instancia_b_6-regulador6)*100/instancia_total_6)))



print ("\n")

print("{} linhas consideradas Benign no dataset original, o que é equivalente a {}% do dataset".format(instancia_b_7, (instancia_b_7*100/instancia_total_7)))
print("{} linhas consideradas Benign no novo dataset original, o que é equivalente a {}% do dataset".format(instancia_novo_b_7, (instancia_novo_b_7*100/instancia_novo_dia7)))
print("Foram removidas {} linhas consideradas Benign do antigo dataset, o que é equivalente a {}% do dataset".format((instancia_b_7-regulador7),((instancia_b_7-regulador7)*100/instancia_total_7)))




print ("\n")

print("{} linhas consideradas Benign no dataset original, o que é equivalente a {}% do dataset".format(instancia_b_8, (instancia_b_8*100/instancia_total_8)))
print("{} linhas consideradas Benign no novo dataset original, o que é equivalente a {}% do dataset".format(instancia_novo_b_8, (instancia_novo_b_8*100/instancia_novo_dia8)))
print("Foram removidas {} linhas consideradas Benign do antigo dataset, o que é equivalente a {}% do dataset".format((instancia_b_8-regulador8),((instancia_b_8-regulador8)*100/instancia_total_8)))


print ("\n")

print("{} linhas consideradas Benign no dataset original, o que é equivalente a {}% do dataset".format(instancia_b_9, (instancia_b_9*100/instancia_total_9)))
print("{} linhas consideradas Benign no novo dataset original, o que é equivalente a {}% do dataset".format(instancia_novo_b_9, (instancia_novo_b_9*100/instancia_novo_dia9)))
print("Foram removidas {} linhas consideradas Benign do antigo dataset, o que é equivalente a {}% do dataset".format((instancia_b_9-regulador9),((instancia_b_9-regulador9)*100/instancia_total_9)))




print ("\n")

print("{} linhas consideradas Benign no dataset original, o que é equivalente a {}% do dataset".format(instancia_b_10, (instancia_b_10*100/instancia_total_10)))
print("{} linhas consideradas Benign no novo dataset original, o que é equivalente a {}% do dataset".format(instancia_novo_b_10, (instancia_novo_b_10*100/instancia_novo_dia10)))
print("Foram removidas {} linhas consideradas Benign do antigo dataset, o que é equivalente a {}% do dataset".format((instancia_b_10-regulador10),((instancia_b_10-regulador10)*100/instancia_total_10)))
# Out:
# 667626 linhas consideradas Benign no dataset original, o que é equivalente a 63.66983763679279% do dataset
# 380949 linhas consideradas Benign no novo dataset original, o que é equivalente a 50.0% do dataset
# Foram removidas 286677 linhas consideradas Benign do antigo dataset, o que é equivalente a 27.33967527358558% do dataset
#
#
# 996077 linhas consideradas Benign no dataset original, o que é equivalente a 94.99339579906064% do dataset
# 52498 linhas consideradas Benign no novo dataset original, o que é equivalente a 50.0% do dataset
# Foram removidas 943579 linhas consideradas Benign do antigo dataset, o que é equivalente a 89.98679159812126% do dataset
#
#
# 1048213 linhas consideradas Benign no dataset original, o que é equivalente a 99.96547695682236% do dataset
# 362 linhas consideradas Benign no novo dataset original, o que é equivalente a 50.0% do dataset
# ...

# %%
novo_dia1.to_csv('novo_dia1.csv', index=False)
novo_dia2.to_csv('novo_dia2.csv', index=False)
novo_dia6.to_csv('novo_dia6.csv', index=False)
novo_dia7.to_csv('novo_dia7.csv', index=False)
novo_dia8.to_csv('novo_dia8.csv', index=False)
novo_dia9.to_csv('novo_dia9.csv', index=False)
novo_dia10.to_csv('novo_dia10.csv', index=False)

# %%
# %%time
df = pd.read_csv('novo_dia1.csv', low_memory=False)
df2 = pd.read_csv('novo_dia2.csv', low_memory=False)

# %%
# Out:
# (1048575, 80)
